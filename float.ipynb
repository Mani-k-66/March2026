# %% [markdown]
# # Question: Calculate the area of a circle with radius 5.5

# %%
import math
radius=5.5
area=math.pi*radius**2
print(f"radius:{radius}")
print(f"area:{area:.2f}")
# Out:
# radius:5.5
# area:95.03

# %% [markdown]
# # Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577

# %%
numbers=3.14, 2.718, 1.618, 0.577
average=sum(numbers)/len(numbers)
print(f"average of numbers{numbers}:{average:.2f}")
# Out:
# average of numbers(3.14, 2.718, 1.618, 0.577):2.01

# %% [markdown]
# # Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)

# %%
fahrenheit=98.6
c=(fahrenheit-32)*5/9
print(f"{fahrenheit} is celsius:{c:.2f}")
# Out:
# 98.6 is celsius:37.00

# %% [markdown]
# # Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years

# %%
p=1000
t=3/365
r=5.5
interest=p*t*r/100
print(f"compound interest (p,t,r) :{interest:.2f}")
# Out:
# compound interest (p,t,r) :0.45

# %% [markdown]
# # Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2

# %%
import math
a=3.5
b=4.2
hypotenuse =math.sqrt(a**2+b**2)
print(f"hypotenuse of a right triangle with sides {a} and {b} is:{hypotenuse:.2f}")
# Out:
# hypotenuse of a right triangle with sides 3.5 and 4.2 is:5.47

# %% [markdown]
# # Question 5: Calculate the volume of a sphere with radius 7.8

# %%
import math
r=7.8
volume=4/3*math.pi*r**3
print(f"volume of a speare with {r} is:{volume:.2f}")
# Out:
# volume of a speare with 7.8 is:1987.80

# %% [markdown]
# # Question 6: Round 3.14159 to 3 decimal places

# %%
number=3.14159
result=round(number,3)
print(f"round {number} :{result}")
# Out:
# round 3.14159 :3.142

# %% [markdown]
# # Question 7: Calculate the percentage: 45 out of 67

# %%
a=45
b=67
percentage=(a/b)*100
print(f" {a} out of {b} :{percentage:.2f}%")
# Out:
#  45 out of 67 :67.16%

# %% [markdown]
# # Question 8: Find the square root of 23.456

# %%
import math
a=23.456
square_root=math.sqrt(a)
print(f"square root of {a} : {square_root:.2f}")
# Out:
# square root of 23.456 : 4.84

# %% [markdown]
# # Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years

# %%
p=2500
r=6.5
t=2.5
simple_intrest=p*t*r/100
print(f"simple intrst (p,t,r) :{simple_intrest:.2f}")
# Out:
# simple intrst (p,t,r) :406.25

# %% [markdown]
# # Question 10: Convert 45.7 degrees to radians

# %%
import math
degrees=45.7
radius=degrees*(math.pi/180)
print(f" {degrees} degrees to {radius:.2f} radius")
# Out:
#  45.7 degrees to 0.80 radius
