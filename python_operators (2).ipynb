# %%
##Arithema Operators
a=10
b=20
c=a+b

# %%
c
# Out:
# 30

# %%
c=a-b

# %%
c
# Out:
# -10

# %%
c-a
# Out:
# -20

# %%
c=a*b

# %%
c
# Out:
# 200

# %%
c%c-a
# Out:
# -10

# %%
c**a
# Out:
# 102400000000000000000000

# %%
b//a
# Out:
# 2

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 10

# %%
print(a)
print(b)
# Out:
# 10
# 20

# %%
a/b
# Out:
# 0.5

# %%
b/a
# Out:
# 2.0

# %%
b//a
# Out:
# 2

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 10

# %%
b%a
# Out:
# 0

# %%
a=20
b=10

# %%
a%b
# Out:
# 0

# %%
b%a
# Out:
# 10

# %% [markdown]
# #comparison operator

# %%
b=20

# %%
a=30

# %%
a==b
# Out:
# False

# %%
name="mani"
student="mani"

# %%
name==student
# Out:
# True

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
print(a==b)
print(a!=b)
print(a<b)
print(a>b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# True
# False

# %%
a
# Out:
# 30

# %%
b
# Out:
# 20

# %% [markdown]
# #Assignment operators

# %%
a=30

# %%
a=a+5

# %%
a
# Out:
# 85

# %%
a
# Out:
# 85

# %%
a=20

# %%
a=b+20

# %%
a
# Out:
# 40

# %%
b
# Out:
# 20

# %%
a+=20

# %%
a
# Out:
# 60

# %%
a-=20

# %%
a
# Out:
# 40

# %%
print(a)
print(b)
# Out:
# 40
# 20

# %%
a = b
print(a)
a = -b
print(a)
a = +b
print(a)
a *= b
print(a)
a %= b
print(a)
a **= b
print(a)
print(a//b)
print(a/b)
# Out:
# 20
# -20
# 20
# 400
# 0
# 0
# 0
# 0.0

# %%
a-=b

# %%
a
# Out:
# 20

# %%
a-=b

# %%
a
# Out:
# -20

# %%
a*=b

# %%
a
# Out:
# -400

# %%
b
# Out:
# 20

# %%
a
# Out:
# -400

# %%
a=20

# %%
a*=b

# %%
a
# Out:
# 400

# %%
a=30

# %%
a/=3

# %%
a
# Out:
# 10.0

# %%
a//=3

# %%
a
# Out:
# 0

# %%
a*=2

# %%
a
# Out:
# 0

# %%
a%=2

# %%
a
# Out:
# 0

# %%
a//2
# Out:
# 0

# %%
a/=5

# %%
a
# Out:
# 0.0

# %%
a=20

# %%
a+=2

# %%
a
# Out:
# 22

# %%
a-=18

# %%
a
# Out:
# 4

# %% [markdown]
# #Logical operator

# %%
name="mani"
student_id="mani"

# %%
result=name and student

# %%
result
# Out:
# 'mani'

# %%
age=21
vote=True
max=18

# %%
print(age>max or vote)
# Out:
# True

# %%
print(age>max and vote)
print(age<max and vote)
print(age<max or vote)
print(age>max or vote)
print(age>max or not vote)
print(age<max or not vote)
# Out:
# True
# False
# True
# True
# True
# False

# %% [markdown]
# #Identity operator

# %%
x=[123]
y=x
z=[123]

# %%
print(x is y)
# Out:
# True

# %%
print(x is not z)
print(x is not y)
print(x is z)
# Out:
# True
# False
# False

# %% [markdown]
# #Membership operator

# %%
fruits=["apple","banana","carry"]

# %%
print("apple" in fruits)
# Out:
# True

# %%
print("mango" in fruits )
# Out:
# False

# %%
print("mango" not in fruits)
# Out:
# True
