# %% [markdown]
# # Question: Check if a number is both even and greater than 10

# %%
number=16
is_even=number%2==0
is_greater_then_10=number>10
result= is_even and is_greater_then_10
print(f"number:{number}")
print(f"is even:{is_even}")
print(f"is greaterb then 10:{is_greater_then_10}")
print(f"both conditions:{result}")
# Out:
# number:16
# is even:True
# is greaterb then 10:True
# both conditions:True

# %% [markdown]
# # Question 1: Check if 25 is greater than 20 and less than 30

# %%
number=25
if number>20 and number<30:
    print(f"{number}:True")
else:
    print(Flase)
# Out:
# 25:True

# %% [markdown]
# # Question 2: Check if string "python" is equal to "Python" (case sensitive)

# %%
word="python"
if word =="Python":
    print("equal")
else:
    print("not equal")
# Out:
# not equal

# %% [markdown]
# # Question 3: Check if 15 is divisible by both 3 and 5

# %%
number=15
if number%3 and number%5:
    print("True")
else:
    print("Flase")
# Out:
# Flase

# %% [markdown]
# # Question 4: Check if 7 is not equal to 8

# %%
number=7
if number==8:
    print("true")
else:
    print("flase")
# Out:
# flase

# %%
if 7!=8:
    print("True")
else:
    print("Flase")
# Out:
# True

# %% [markdown]
# # Question 5: Check if 100 is greater than 50 or less than 25

# %%
number=100
if number>50 or number<25:
    print("True")
else:
    print("Flase")
# Out:
# True

# %% [markdown]
# # Question 6: Check if 0 is falsy in Python

# %%
number=0
if number:
    print("True")
else:
    print("Flase")
# Out:
# Flase

# %% [markdown]
# # Question 6: Check if 0 is falsy in Python

# %%
num=0
if not num:
    print("0 is falsy")
else:
    print("0 is truthy")
# Out:
# 0 is falsy

# %% [markdown]
# # Question 7: Check if empty string "" is falsy in Python

# %%
string=""
if not string:
    print("empty string is falsy")
else:
    print("empty string is truthy")
# Out:
# empty string is falsy

# %% [markdown]
# # Question 8: Check if 42 is truthy in Python

# %%
num=42
if num:
    print("truthy")
else:
    print("falsy")
# Out:
# truthy

# %% [markdown]
# # Question 9: Check if 10 is between 5 and 15 (inclusive)

# %%
num=10
if 5<= num <=15:
    print("True")
else:
    print("Flase")
# Out:
# True
