# %% [markdown]
# # Question: Check if a variable is None

# %%
variable=None
is_none=variable is None
print(f"variable:{variable}")
print(f"Is None:{is_none}")
# Out:
# variable:None
# Is None:True

# %% [markdown]
# # Question 1: Create a variable and assign None to it

# %%
variable=None
print(f"variable:{variable}")
# Out:
# variable:None

# %% [markdown]
# # Question 2: Check if None equals None

# %%
word=None==None
print(f"None==None: {word}")
# Out:
# None==None: True

# %% [markdown]
# # Question 3: Check if None is None

# %%
word=None is None
print(word)
# Out:
# True

# %% [markdown]
# # Question 4: Check if 0 is None

# %%
num=0
result=num is None
print(f"{num} is {result}")
# Out:
# 0 is False

# %% [markdown]
# # Question 5: Check if empty string is None

# %%
empty=""
result=empty is None
print(f"{empty} is {result}")
# Out:
#  is False

# %% [markdown]
# # Question 6: Check if False is None

# %%
bool_val=False
result=bool_val is None
print(f"{bool_val} is {result}")
# Out:
# False is False

# %% [markdown]
# # Question 7: Check if empty list is None

# %%
list=[]
result=list is None
print(f"{list} is {result}")
# Out:
# [] is False

# %% [markdown]
# # Question 8: Check if empty dictionary is None

# %%
dictionary={}
result=dictionary is None
print(f"{dictionary} is {result}")
# Out:
# {} is False

# %% [markdown]
# # # Question 9: Check if empty tuple is None

# %%
tuple=()
result=tuple is None
print(f"{tuple} is {result}")
# Out:
# () is False

# %% [markdown]
# # Question 10: Check if empty set is None

# %%
set=set()
result=set is None
print(f"{set} is {result}")
# Out:
# set() is False
