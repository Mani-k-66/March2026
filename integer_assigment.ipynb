# %%
first_5_even=[2,4,6,8,10]
sum_nums=sum(first_5_even)
print(f"the even numbers are: {first_5_even}")
print(f"the sum of 5 even numbers:{sum_nums}")
print("="*50)
# Out:
# the even numbers are: [2, 4, 6, 8, 10]
# the sum of 5 even numbers:30
# ==================================================

# %% [markdown]
# # Question 1: Calculate the product of first 10 natural numbers

# %%
product=1
for i in range(1,11):
    product=product*i
    print(f"natural nums:{i}")
print(f"the product of nums:{product}")
# Out:
# natural nums:1
# natural nums:2
# natural nums:3
# natural nums:4
# natural nums:5
# natural nums:6
# natural nums:7
# natural nums:8
# natural nums:9
# natural nums:10
# the product of nums:3628800

# %% [markdown]
# # Question 2: Find the remainder when 156 is divided by 7

# %%
number=156
remainder=number%7
print(f"number:{remainder}")
# Out:
# number:2

# %% [markdown]
# # Question 3: Calculate the square of 25

# %%
number=25
square=square**0.5
print(f"the square  of {number} is: {square}")
# Out:
# the square  of 25 is: 5.0

# %% [markdown]
# # Question 4: Find the cube root of 125

# %%
cube=125
cube_root=cube**(1/3)
print(f"the cube root of {number} is:{cube_root}")
# Out:
# the cube root of 25 is:4.999999999999999

# %% [markdown]
# # Question 5: Calculate the sum of digits in number 12345

# %%
digits=12345
for digit in digits:
    sum_number=sum(int(digit) for digit in str(digits))

# %% [markdown]
# # Question 6: Check if 97 is a prime number

# %%
number=97
if number %2==0:
    print(f"the number is prime number:{number}")
else:
        print(f"the number is not prime number")
# Out:
# the number is not prime number

# %% [markdown]
# # Question 7: Find the factorial of 8

# %%
number=8
fact=1
for i in range(1,number+1):
    fact=fact*i
print(f"The factorial of {number} is {fact}")
# Out:
# The factorial of 8 is 40320

# %% [markdown]
# # Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56

# %%
numbers=[15,23,31,42,56]
avg_num=sum(numbers)
avg_num/len(numbers)
print(f"the average of numbers:{avg_num}")
# Out:
# the average of numbers:167

# %% [markdown]
# # Question 9: Find the greatest common divisor (GCD) of 48 and 36

# %%
import math
a=48
b=36
result=math.gcd(a,b)
print(f"the gretest common divisor {a} and {b} is:{result}")
# Out:
# the gretest common divisor 48 and 36 is:12

# %% [markdown]
# # Question 10: Calculate the sum of first 20 odd numbers

# %%
numbers=range(1,40)
sum_odd=0
for i in numbers:
    if i%2==1:
        sum_odd+=i
print(f"the sum of first 20 odd numbers: {sum_odd}")
# Out:
# the sum of first 20 odd numbers: 400
