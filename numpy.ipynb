# %%
import numpy as nd

# %%
l=[1,2,3]
type(l)
# Out:
# list

# %%
list((1,2,3))
# Out:
# [1, 2, 3]

# %%
nd.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
x=[1,2,3]
y=nd.array([1,2,3])
type(x),type(y)
# Out:
# (list, numpy.ndarray)

# %%
x=nd.arange(100,110)
print(x)
# Out:
# [100 101 102 103 104 105 106 107 108 109]

# %%
x=nd.linspace(3,5,5)
print(x)
# Out:
# [3.  3.5 4.  4.5 5. ]
